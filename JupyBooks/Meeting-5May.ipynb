# %% [markdown]
# # Meeting 6-May
#
# This meeting covers the following topics:
#
# - A new control analysis was generated to quantify extinction impact both at the full community level and within the subcommunity formed by surviving species. Both models were evaluated with and without node features, with results showing no significant performance difference between the two conditions.
#
# - Building on this, the best-performing GraphConv model was applied to random interaction network communities to quantify the effect of node statistics. As expected, node features proved important in this dataset, given the absence of a clear structural pattern identifying the most relevant node.
#
# - Confusion matrices are presented for both models.

# %%
from IPython.display import HTML
path = '/home/mriveraceron/Results/NegCtrl-V1/Raw-Dummy'

HTML(f'''
    <figure>
        <img src="{path}/Dummy_loss_plot.png" width="700">
        <figcaption style="text-align:center; font-style:italic; color:gray;">
            Figure 1: Loss history plot for Dummy model
        </figcaption>
    </figure>
''')

# %% [markdown]
# ## New control analysis

# %%
dir = '/home/mriveraceron/glv-research/Results/gnn_proof'
